# %% [markdown]
# # Notebook 5 - Multi-Drone Scheduling
#
# Roadmap role: Week 5. Literature-driven rule: compare classical allocation baselines under shared metrics before using LLM assignment.

# %%
print('Scheduling work starts after mission tasks and simulated drone states are defined.')
