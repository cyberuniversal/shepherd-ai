# %% [markdown]
# # Notebook 1 - Environment Setup and Shepherd-AI Exploration
#
# Roadmap role: Week 1 setup. Technical rules come from `AGENTS.md` and `docs/literature_to_implementation.md`.

# %%
from pathlib import Path
ROOT = Path.cwd()
print(ROOT)
for required in ['AGENTS.md', 'docs/roadmap.pdf', 'docs/literature_to_implementation.md']:
    print(required, (ROOT / required).exists())

# %% [markdown]
# Before experiments, read the mandatory source documents. Do not report implementation status from the roadmap alone.
