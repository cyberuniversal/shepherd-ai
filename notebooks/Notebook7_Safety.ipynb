# %% [markdown]
# # Notebook 7 - Safety and Feedback
#
# Roadmap role: Week 7. Literature-driven rule: deterministic validators and runtime monitors gate execution; LLM output is not trusted by default.

# %%
print('Safety work starts after plans, schedules, drone states, and map constraints exist.')
